# %%
### Note
* Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#Calculating the school count

school_count = len(school_data_complete["school_name"].unique())
school_count
# Out:
# 15

# %%
#Calculating the student count

student_count = len(school_data_complete["Student ID"].unique())
student_count
# Out:
# 39170

# %%
#Calculating the total budget

unique_budget = school_data_complete["budget"].unique()
total_budget = sum(unique_budget)
total_budget
# Out:
# 24649428

# %%
#Calculating the average math score

average_mathscore = school_data_complete["math_score"].mean()
average_mathscore
# Out:
# 78.98537145774827

# %%
#Calculating the average reading score

average_readingscore = school_data_complete["reading_score"].mean()
average_readingscore
# Out:
# 81.87784018381414

# %%
#Calculating the passing math score (equal or greater than 70%)

passing_mathscore = (school_data_complete[school_data_complete["math_score"]>=70]["student_name"].count()/student_count)*100
passing_mathscore
# Out:
# 74.9808526933878

# %%
#Calculating the passing reading score

passing_readingscore = (school_data_complete[school_data_complete["reading_score"]>=70]["student_name"].count()/student_count)*100
passing_readingscore
# Out:
# 85.80546336482001

# %%
#Calculating the overall pass rate (both reading and math)

overall_passing = (school_data_complete[(school_data_complete["math_score"]>=70) & (school_data_complete["reading_score"]>=70)]["school_name"].count()/student_count)*100
overall_passing
# Out:
# 65.17232575950983

# %% [markdown]
# # Creating Summary Dataframe

# %%
district_summary = {"Total Schools": school_count,
                   "Total Students": '{:,}'.format(student_count),
                   "Total Budget": '${:,.2f}'.format(total_budget),
                   "Average Math Score": '{:,.2f}'.format(average_mathscore),
                   "Average Reading Score": '{:,.2f}'.format(average_readingscore),
                    "% Passing Math": '{:,.4f}'.format(passing_mathscore),
                    "% Passing Reading": '{:,.4f}'.format(passing_readingscore),
                     "% Overall Passing":[round(overall_passing)]
                   }
district_summary_df = pd.DataFrame(district_summary)
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.00              78.99
#
#   Average Reading Score % Passing Math % Passing Reading  % Overall Passing
# 0                 81.88        74.9809           85.8055               65.0

# %% [markdown]
# ## School Summary

# %%
#School name grouped by schools
school_name = school_data_complete.groupby(["school_name"])
school_name.count()
# Out:
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4976          4976    4976   4976           4976
# Cabrera High School          1858          1858    1858   1858           1858
# Figueroa High School         2949          2949    2949   2949           2949
# Ford High School             2739          2739    2739   2739           2739
# Griffin High School          1468          1468    1468   1468           1468
# Hernandez High School        4635          4635    4635   4635           4635
# Holden High School            427           427     427    427            427
# Huang High School            2917          2917    2917   2917           2917
# Johnson High School          4761          4761    4761   4761           4761
# Pena High School              962           962     962    962            962
# Rodriguez High School        3999          3999    3999   3999           3999
# ...

# %%
#Identifying the school type
school_type = school_name["type"].first()
school_type
# Out:
# school_name
# Bailey High School       District
# Cabrera High School       Charter
# Figueroa High School     District
# Ford High School         District
# Griffin High School       Charter
# Hernandez High School    District
# Holden High School        Charter
# Huang High School        District
# Johnson High School      District
# Pena High School          Charter
# Rodriguez High School    District
# Shelton High School       Charter
# Thomas High School        Charter
# Wilson High School        Charter
# Wright High School        Charter
# Name: type, dtype: object

# %%
#Total Students
total_students = school_name.size()
total_students
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# dtype: int64

# %%
#Total School Budget
school_budget = school_name["budget"].first()
school_budget
# Out:
# school_name
# Bailey High School       3124928
# Cabrera High School      1081356
# Figueroa High School     1884411
# Ford High School         1763916
# Griffin High School       917500
# Hernandez High School    3022020
# Holden High School        248087
# Huang High School        1910635
# Johnson High School      3094650
# Pena High School          585858
# Rodriguez High School    2547363
# Shelton High School      1056600
# Thomas High School       1043130
# Wilson High School       1319574
# Wright High School       1049400
# Name: budget, dtype: int64

# %%
#Per Student Budget
per_studentbudget = school_budget/total_students
per_studentbudget
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#Average Math Score
average_mathscore = school_name["math_score"].mean()
average_mathscore
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#Average ReadingScore
average_readingscore = school_name["reading_score"].mean()
average_readingscore
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
#Percentage Passing Math
passingpercentage_math = school_data_complete[school_data_complete["math_score"]>=70].groupby(["school_name"]).count()["Student ID"]/total_students
passingpercentage_math
# Out:
# school_name
# Bailey High School       0.666801
# Cabrera High School      0.941335
# Figueroa High School     0.659885
# Ford High School         0.683096
# Griffin High School      0.933924
# Hernandez High School    0.667530
# Holden High School       0.925059
# Huang High School        0.656839
# Johnson High School      0.660576
# Pena High School         0.945946
# Rodriguez High School    0.663666
# Shelton High School      0.938671
# Thomas High School       0.932722
# Wilson High School       0.938677
# Wright High School       0.933333
# dtype: float64

# %%
#Percentage Passing Reading
passingpercentage_reading = school_data_complete[school_data_complete["reading_score"]>=70].groupby(["school_name"]).count()["Student ID"]/total_students
passingpercentage_reading
# Out:
# school_name
# Bailey High School       0.819333
# Cabrera High School      0.970398
# Figueroa High School     0.807392
# Ford High School         0.792990
# Griffin High School      0.971390
# Hernandez High School    0.808630
# Holden High School       0.962529
# Huang High School        0.813164
# Johnson High School      0.812224
# Pena High School         0.959459
# Rodriguez High School    0.802201
# Shelton High School      0.958546
# Thomas High School       0.973089
# Wilson High School       0.965396
# Wright High School       0.966111
# dtype: float64

# %%
# Students who passed both reading and math in a separate DataFrame.
passing_math_and_reading = school_data_complete[(school_data_complete["reading_score"] >= 70)
                                               & (school_data_complete["math_score"] >= 70)]
passing_math_and_reading.count()
# Out:
# Student ID       25528
# student_name     25528
# gender           25528
# grade            25528
# school_name      25528
# reading_score    25528
# math_score       25528
# School ID        25528
# type             25528
# size             25528
# budget           25528
# dtype: int64

# %%
#Percentage Overall Passing Both Reading and Math
percentageoverall_passing = school_data_complete[(school_data_complete["reading_score"] >= 70)
                                               & (school_data_complete["math_score"] >= 70)].groupby(["school_name"]).count()["student_name"]/total_students * 100
percentageoverall_passing

#passingpercentage_math = school_data_complete[school_data_complete["math_score"]>=70].groupby(["school_name"]).count()["Student ID"]/total_students
#passingpercentage_math
#passingpercentage_reading = school_data_complete[school_data_complete["reading_score"]>=70].groupby(["school_name"]).count()["Student ID"]/total_students
#passingpercentage_reading
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
#Creating Dataframe to display school results!

school_level_summary = {"School Type": school_type,
                   "Total Students": (total_students),
                   "Total School Budget": (school_budget),
                   "Per Student Budget": (per_studentbudget),
                   "Average Math Score": (average_mathscore),
                    "Average Reading Score": (average_readingscore), 
                    "% Passing Math": (passingpercentage_math),
                    "% Passing Reading": (passingpercentage_reading),
                     "% Overall Passing": percentageoverall_passing
                   }

#Formatting
school_level_summary["Total School Budget"] = school_level_summary["Total School Budget"].map("${:,.2f}".format)
school_level_summary["Per Student Budget"] = school_level_summary["Per Student Budget"].map("${:,.2f}".format)

school_level_summary_df = pd.DataFrame(school_level_summary)
school_level_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
# Displaying the top 5 performing schools by Overall Passing Percentage To sort from highest to lowest, ascending=False must be passed in
topfiveschools_df = school_level_summary_df.sort_values("% Overall Passing", ascending=False)
topfiveschools_df.head(5)
# Out:
#                     School Type  Total Students Total School Budget  \
# school_name
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %%
## Displaying the lowest 5 performing schools by Overall Passing Percentage 
bottomfiveschools_df = school_level_summary_df.sort_values("% Overall Passing", ascending=True)
bottomfiveschools_df.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Rodriguez High School              80.744686        0.663666
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# Create data series of scores by grade levels using conditionals
#Create series for 9th, 10th, 11th, 12th Grades
ninth_grade = school_data_complete[(school_data_complete['grade'] == "9th")]
tenth_grade = school_data_complete[(school_data_complete['grade'] == "10th")]
eleventh_grade = school_data_complete[(school_data_complete['grade'] == "11th")]
twelfth_grade = school_data_complete[(school_data_complete['grade'] == "12th")]

# %%
# Group each series by school name
ninth_grade_byschool = ninth_grade.groupby("school_name").mean()["math_score"]
tenth_grade_byschool = tenth_grade.groupby("school_name").mean()["math_score"]
eleventh_grade_byschool = eleventh_grade.groupby("school_name").mean()["math_score"]
twelfth_grade_byschool = twelfth_grade.groupby("school_name").mean()["math_score"]

# %%
ninth_grade_byschool
tenth_grade_byschool
# Out:
# school_name
# Bailey High School       76.996772
# Cabrera High School      83.154506
# Figueroa High School     76.539974
# Ford High School         77.672316
# Griffin High School      84.229064
# Hernandez High School    77.337408
# Holden High School       83.429825
# Huang High School        75.908735
# Johnson High School      76.691117
# Pena High School         83.372000
# Rodriguez High School    76.612500
# Shelton High School      82.917411
# Thomas High School       83.087886
# Wilson High School       83.724422
# Wright High School       84.010288
# Name: math_score, dtype: float64

# %%
# Combine series into single DataFrame
scores_by_grade_by_school = pd.DataFrame({"9th": ninth_grade_byschool, "10th": tenth_grade_byschool,
                                "11th": eleventh_grade_byschool, "12th": twelfth_grade_byschool})

# %%
# Display the DataFrame
scores_by_grade_by_school
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
# Create data series of scores by grade levels using conditionals
#Create series for 9th, 10th, 11th, 12th Grades
ninth_grade = school_data_complete[(school_data_complete['grade'] == "9th")]
tenth_grade = school_data_complete[(school_data_complete['grade'] == "10th")]
eleventh_grade = school_data_complete[(school_data_complete['grade'] == "11th")]
twelfth_grade = school_data_complete[(school_data_complete['grade'] == "12th")]

# %%
# Group each series by school name
ninth_grade_byschool_reading = ninth_grade.groupby("school_name").mean()["reading_score"]
tenth_grade_byschool_reading = tenth_grade.groupby("school_name").mean()["reading_score"]
eleventh_grade_byschool_reading = eleventh_grade.groupby("school_name").mean()["reading_score"]
twelfth_grade_byschool_reading = twelfth_grade.groupby("school_name").mean()["reading_score"]

# %%
# Combine series into single DataFrame
scores_by_grade_by_school_reading = pd.DataFrame({"9th": ninth_grade_byschool, "10th": tenth_grade_byschool,
                                "11th": eleventh_grade_byschool, "12th": twelfth_grade_byschool})

# %%
# Display the DataFrame
scores_by_grade_by_school_reading
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$584                                       83.46                  83.93
# $585-629                                    81.90                  83.16
# $630-644                                    78.52                  81.62
# $645-675                                    77.00                  81.03
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$584                                   93.46              96.61
# $585-629                                87.13              92.72
# $630-644                                73.48              84.39
# $645-675                                66.16              81.13
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$584                                      90.37
# $585-629                                   81.42
# ...

# %%
# Create bins in which to place spending ranges 
#bins = [0, 585, 630, 645, 675]

#create labels for these bins
#group_labels = ["<$584k", "$585-629", "$630-644", "$645-675k"]

#bins = [0, 199999, 399999, 599999, 799999, 999999,
        #1999999, 2999999, 3999999, 4999999, 50000000]
# Create labels for these bins
#group_labels = ["0 to 199k", "200k to 399k", "400k to 599k", "600k to 799k", "800k to 999k", "1mil to 2mil",
                #"2mil to 3mil", "3mil to 4mil", "4mil to 5mil", "5mil to 50mil"]

# %%
school_level_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %%
# Using the school_level_summary DataFrame that was created earlier and remaning it 
#school_level_summary_df = scores_by_spending_school_level_summary

# %%
#Dropping uneeded columns from the dataframe
school_level_summary_df.drop(columns=["School Type", "Total Students", "Total School Budget", "Per Student Budget"])


cut_labels_4 = ['<$585', '$585-629', '$630-644', '$645-675k']
cut_bins = [0, 585, 630, 645, 675]
school_level_summary_df['Spending Ranges(Per Student)'] = pd.cut('Per Student Budget', bins=cut_bins, labels=cut_labels_4)
#school_level_summary_df

# Create bins in which to place spending ranges 
#bins = [0, 585, 630, 645, 675]

#create labels for these bins
#group_labels = ["<$584k", "$585-629", "$630-644", "$645-675k"]

#school_level_summary_df["School Size"] = pd.cut(school_level_summary_df["Total Students"], bins, labels=group_labels)
#school_level_summary_df

# Calculations can also be performed on Series and added into DataFrames as new columns
#thousands_of_dollars = data_file_df["Amount"]/1000
#data_file_df["Thousands of Dollars"] = thousands_of_dollars

#school_level_summary_df.add(["Spending Ranges(Per Student)"])
#average_donation = hosted_in_us_df['pledged']


#df.drop(columns=['B', 'C'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-7155e26723ec> in <module>
#       5 cut_labels_4 = ['<$585', '$585-629', '$630-644', '$645-675k']
#       6 cut_bins = [0, 585, 630, 645, 675]
# ----> 7 school_level_summary_df['Spending Ranges(Per Student)'] = pd.cut('Per Student Budget', bins=cut_bins, labels=cut_labels_4)
#       8 #school_level_summary_df
#       9
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     204
#     205     original = x
# --> 206     x = _preprocess_for_cut(x)
#     207     x, dtype = _coerce_to_type(x)
#     208
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/tile.py in _preprocess_for_cut(x)
#     553         x = np.asarray(x)
#     554     if x.ndim != 1:
# ...

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
